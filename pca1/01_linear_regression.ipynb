# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(42)

x=np.random.rand(10,1)
print(x)
# Out:
# [[0.37454012]
#  [0.95071431]
#  [0.73199394]
#  [0.59865848]
#  [0.15601864]
#  [0.15599452]
#  [0.05808361]
#  [0.86617615]
#  [0.60111501]
#  [0.70807258]]

# %%
y=3+4*x+0.2*np.random.randn(10,1)
print(y)
# Out:
# [[4.31655566]
#  [6.52039649]
#  [6.22110552]
#  [5.34947868]
#  [3.6375802 ]
#  [3.33902844]
#  [3.1234579 ]
#  [6.4868891 ]
#  [5.17426133]
#  [5.90742991]]

# %%
plt.scatter(x,y,c="y",alpha=0.5,marker="*")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
